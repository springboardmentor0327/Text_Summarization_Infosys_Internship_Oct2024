# %% [markdown]
# Installing Libraries

# %%
# !pip install -U gradio langchain langchain-community pypdf langchain-google-genai langgraph --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 MB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 48.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.0/125.0 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 66.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 50.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.6 MB/s eta 0:00:00

# %% [markdown]
# Insert API Key

# %%
from google.colab import userdata
import os
os.environ['GOOGLE_API_KEY'] = userdata.get('GOOGLE_API_KEY')

# %% [markdown]
# Importing Libraries

# %%
from langchain.document_loaders import PyPDFLoader
from langchain.chains.summarize import load_summarize_chain
import gradio as gr

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
      model="gemini-1.5-flash",
      temperature=0,
      max_tokens=None,
      timeout=None,
      max_retries=2
)

# %%
def summarize_pdf(pdf_file_path):
    loader = PyPDFLoader(pdf_file_path)
    docs = loader.load_and_split()
    chain = load_summarize_chain(llm, chain_type="refine")
    summary = chain.invoke(docs)

    return summary['output_text']

# %% [markdown]
# Enter Document Path

# %%
summary = summarize_pdf("/content/Ukkonen's_algorithm_Wikipedia.pdf")

# %% [markdown]
# Printing the Summary

# %%
print(summary)
# Out:
# Ukkonen's algorithm is a linear-time, online algorithm for constructing suffix trees.  It iteratively builds the suffix tree for prefixes of the input string, adding one character at a time. This online approach, combined with three extension rules that handle different scenarios during character addition, achieves O(n) time complexity for constant-size alphabets (O(n log n) in general). The algorithm uses implicit suffix trees, avoiding unnecessary nodes and edges during intermediate steps, representing a significant improvement over earlier algorithms with O(n²) or O(n³) time complexities.  Unlike naive approaches, Ukkonen's algorithm cleverly leverages algorithmic techniques to achieve linear time by extending existing paths or creating new leaf nodes based on whether the next character is already present in the tree.  The algorithm's efficiency is well-documented, with numerous resources available including academic papers (e.g.,  Ukkonen's original 1995 paper and McCreight's earlier work), tutorials, and various implementations in languages like C and C++.  These resources provide detailed explanations and examples illustrating the algorithm's mechanics and practical application.
