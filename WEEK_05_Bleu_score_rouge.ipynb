# %%
# !pip install torch transformers datasets sumy scikit-learn nltk rouge-score openpyxl
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.3/97.3 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 80.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.3 MB/s eta 0:00:00
# ...
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=91a2ce0cbc7a7a941dbc5063a9c7cde2da64568f31b80b5ec1bddf4f408f1a93
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !pip install torch transformers datasets

# %%
# !pip install torch transformers datasets nltk sumy scikit-learn sentence-transformers rouge-score openpyxl

# %%
import torch
from transformers import T5ForConditionalGeneration, T5Tokenizer, BartForConditionalGeneration, BartTokenizer, PegasusForConditionalGeneration, PegasusTokenizer
from datasets import load_dataset
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.summarizers.kl import KLSummarizer
from sklearn.cluster import KMeans
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from rouge_score import rouge_scorer
from sentence_transformers import SentenceTransformer
import pandas as pd
from openpyxl import Workbook
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/15.6k [00:00<?, ?B/s]
# train-00000-of-00003.parquet:   0%|          | 0.00/257M [00:00<?, ?B/s]
# train-00001-of-00003.parquet:   0%|          | 0.00/257M [00:00<?, ?B/s]
# train-00002-of-00003.parquet:   0%|          | 0.00/259M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/34.7M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/30.0M [00:00<?, ?B/s]
# ...

# %%
dataset = load_dataset("cnn_dailymail", "3.0.0", split="test[:10]")

# %%
def extractive_summary(text, method='luhn'):
    parser = PlaintextParser.from_string(text, Tokenizer("english"))
    if method == 'luhn':
        summarizer = LuhnSummarizer()
    elif method == 'kl':
        summarizer = KLSummarizer()
    summary = " ".join([str(sentence) for sentence in summarizer(parser.document, 5)])
    return summary

# %%
def kmeans_summary(text, n_clusters=5):
    sentences = text.split('. ')
    if len(sentences) < n_clusters:
        return ". ".join(sentences)


    sentence_embeddings = sentence_model.encode(sentences)


    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(sentence_embeddings)


    cluster_centers = kmeans.cluster_centers_
    summary_sentences = []
    for center in cluster_centers:
        closest_sentence_idx = torch.argmin(torch.tensor([torch.norm(torch.tensor(embedding) - torch.tensor(center)) for embedding in sentence_embeddings]))
        summary_sentences.append(sentences[closest_sentence_idx])

    summary = " ".join(summary_sentences)
    return summary

# %%
def calculate_scores(reference, hypothesis):
    smoothing = SmoothingFunction().method1
    bleu_score = sentence_bleu([reference.split()], hypothesis.split(), smoothing_function=smoothing)
    rouge = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge_scores = rouge.score(reference, hypothesis)
    return bleu_score, rouge_scores['rouge1'].fmeasure, rouge_scores['rouge2'].fmeasure, rouge_scores['rougeL'].fmeasure


    extractive_methods = ['kmeans', 'luhn', 'kl']

    for model_name, (model, tokenizer) in models.items():
        ws = wb.create_sheet(title=model_name)
        ws.append(["Text", "Generated Summary", "BLEU", "ROUGE-1", "ROUGE-2", "ROUGE-L"])
        for item in dataset:
            text = item['article']
            reference_summary = item['highlights']
            generated_summary = abstractive_summary(text, model, tokenizer)
            bleu, rouge1, rouge2, rougeL = calculate_scores(reference_summary, generated_summary)
            ws.append([text, generated_summary, bleu, rouge1, rouge2, rougeL])

    for method in extractive_methods:
        ws = wb.create_sheet(title=method.upper())
        ws.append(["Text", "Extracted Summary", "BLEU", "ROUGE-1", "ROUGE-2", "ROUGE-L"])
        for item in dataset:
            text = item['article']
            reference_summary = item['highlights']
            if method == 'kmeans':
                generated_summary = kmeans_summary(text)
            else:
                generated_summary = extractive_summary(text, method)
            bleu, rouge1, rouge2, rougeL = calculate_scores(reference_summary, generated_summary)
            ws.append([text, generated_summary, bleu, rouge1, rouge2, rougeL])

    wb.remove(wb['Sheet'])
    wb.save("summarization_results.xlsx")
    print("Results saved to summarization_results.xlsx")


process_and_save_results()
