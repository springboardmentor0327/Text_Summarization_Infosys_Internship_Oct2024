# %%
# !pip install transformers datasets rouge-score -q

# %%
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
from datasets import load_dataset
from rouge_score import rouge_scorer

# %%
def load_model(model_name):
  tokenizer = T5Tokenizer.from_pretrained(model_name)
  model = T5ForConditionalGeneration.from_pretrained(model_name)
  return model, tokenizer

# %%
dataset = load_dataset("cnn_dailymail", "3.0.0", split="test")
texts = dataset['article'][6:11]
references = dataset['highlights'][6:11]

# %%
def summarize(text, model, tokenizer):
    input_ids = tokenizer.encode(text, return_tensors="pt", max_length=512, truncation=True)
    with torch.no_grad():
        output = model.generate(input_ids, max_length=150, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(output[0], skip_special_tokens=True)
    return summary

# %%
def calculate_rouge(summaries, references,model_name):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = { 'rouge1': 0, 'rouge2': 0, 'rougeL': 0 }
    i=0
    for summary, reference in zip(summaries, references):
        i+=1

        score = scorer.score(reference, summary)
        print(f'rouge1 score of summary{i}:{score["rouge1"].fmeasure}')
        print(f'rouge2 score of summary{i}:{score["rouge2"].fmeasure}')
        print(f'rougeL score of summary{i}:{score["rougeL"].fmeasure}')
        scores['rouge1'] += score['rouge1'].fmeasure
        scores['rouge2'] += score['rouge2'].fmeasure
        scores['rougeL'] += score['rougeL'].fmeasure
        ws.cell(row=i+1, column=4, value=scores['rouge1'])
        ws.cell(row=i+1, column=5, value=scores['rouge2'])
        ws.cell(row=i+1, column=6, value=scores['rougeL'])

    num_samples = len(summaries)
    scores = { k: v / num_samples for k, v in scores.items() }
    for j, val in enumerate(scores.values()):
        ws.cell(row=i+2, column=j+4, value=val)
    return scores

# %%
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction

def calculate_bleu(summaries, references, model_name):

    bleu_scores = []
    smoothie = SmoothingFunction().method4
    i=0
    for summary, reference in zip(summaries, references):
        i+=1
        reference_tokens = [reference.split()]
        summary_tokens = summary.split()

        score = sentence_bleu(reference_tokens, summary_tokens,weights=(0.5,0.5,0,0) ,smoothing_function=smoothie)
        bleu_scores.append(score)
        print(f"BLEU score of summary{i}: {score}")
        ws.cell(row=i+1, column=7, value=score)

    average_bleu = sum(bleu_scores) / len(bleu_scores)
    ws.cell(row=i+2, column=7, value=average_bleu)
    return average_bleu

# %%
def run_summarization(model_name):
  model, tokenizer = load_model(model_name)

  summaries = [summarize(text, model, tokenizer) for text in texts]

  for i, summary in enumerate(summaries):
    print(f"\nGenerated Summary {i+1} ({model_name}):\n", summary)
  column=['Text',"reference Summary","Summary","rouge 1","rouge 2","rouge L","Bleu score"]
  for i,val in enumerate(column):
      ws.cell(row=1, column=i+1, value=val)
  for i, text in enumerate(texts):
      ws.cell(row=i+2, column=1, value=text)
  for i, summary in enumerate(summaries):
      ws.cell(row=i+2, column=3, value=summary)
  for i, ref in enumerate(references):
      ws.cell(row=i+2, column=2, value=ref)

  rouge_scorers = calculate_rouge(summaries, references,model_name)
  print(f"\nROUGE Scores for {model_name}:", rouge_scorers)
  bleu_score = calculate_bleu(summaries, references,model_name)
  print(f"Average BLEU score: {bleu_score}")

# %%
# !pip install openpyxl
import openpyxl
from openpyxl import Workbook , load_workbook
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (2.0.0)

# %%
wb = wb = load_workbook('/content/drive/My Drive/summary_results.xlsx')

# %%
ws = wb.create_sheet(title="t5-small")

# %%
run_summarization("t5-small")
# Out:
# Generated Summary 1 (t5-small):
#  the number of executions worldwide has gone down by almost 22% on the previous year. at least 607 people were executed around the world in 2014, compared to 778 in 2013. the number of executions worldwide has gone down by almost 22% on the previous year.
#
# Generated Summary 2 (t5-small):
#  : "A rise in my blood pressure places me in grave risk of substantial and irreparable injury or death" a coroner's preliminary assessment is there was no foul play involved in the death of Andrew Getty. the grandson of oil tycoon J. Paul Getty appears to have died of natural causes.
#
# Generated Summary 3 (t5-small):
#  5 p.m. (5 a.m. ET) and heading west at a 12.5 mph clip. it's expected to make landfall on the southeastern coast of Isabela province and be out of the Philippines by Monday.
#
# Generated Summary 4 (t5-small):
#  (CNN)For the first time in eight years, a TV legend returned to doing what he does best. contestants told to "come on down!" on the April 1 edition of "The Price Is Right" encountered not host Drew Carey but another familiar face in charge of the proceedings.
#
# Generated Summary 5 (t5-small):
#  to appear in Westminster Magistrates' Court on Wednesday. Yahya Rashid, a 19-year-old man from northwest London, was detained at Luton airport on Tuesday. he's been charged with engaging in conduct in preparation of acts of terrorism.
# rouge1 score of summary1:0.46
# rouge2 score of summary1:0.26530612244897955
# rougeL score of summary1:0.34
# rouge1 score of summary2:0.3157894736842105
# rouge2 score of summary2:0.08602150537634408
# rougeL score of summary2:0.1263157894736842
# rouge1 score of summary3:0.22222222222222224
# rouge2 score of summary3:0.03278688524590164
# rougeL score of summary3:0.22222222222222224
# rouge1 score of summary4:0.2686567164179105
# rouge2 score of summary4:0.12307692307692307
# rougeL score of summary4:0.23880597014925375
# rouge1 score of summary5:0.4444444444444444
# rouge2 score of summary5:0.17142857142857143
# rougeL score of summary5:0.33333333333333337
#
# ROUGE Scores for t5-small: {'rouge1': 0.34222257135375755, 'rouge2': 0.13572400151534394, 'rougeL': 0.2521354630356987}
# BLEU score of summary1: 0.2623096837197767
# BLEU score of summary2: 0.06262242910851495
# BLEU score of summary3: 0.06881023532039754
# BLEU score of summary4: 0.12903971808580209
# BLEU score of summary5: 0.1951800145897066
# Average BLEU score: 0.1435924161648396

# %%
ws = wb.create_sheet(title="t5-base")

# %%
run_summarization("t5-base")
# Out:
# Generated Summary 1 (t5-base):
#  the threat of terrorism to advance executions, Amnesty International alleges in its annual report on the death penalty. on one hand, the number of executions worldwide has gone down by almost 22% on the previous year. at least 2,466 people were confirmed to have been sentenced to death in 2014, an increase of 28%. "We are seeing a decrease in the number of executions (worldwide)," Audrey Gaughran, Amnesty's Director of Global Issues, told CNN
#
# Generated Summary 2 (t5-base):
#  the coroner's preliminary assessment is there was no foul play involved in the death of Andrew Getty, a police spokesman said. Getty is one of three living sons of oil tycoon J. Paul Getty, who died in 1976. he spearheaded the controversial sale of Getty to Texaco for $10 billion in 1984.
#
# Generated Summary 3 (t5-base):
#  tourists will be advised to return to their respective places... and will be advised to return to their respective places," an official told PNA. Maysak is expected to make landfall Sunday morning on the southeastern coast of Isabela province and be out of the Philippines by Monday.
#
# Generated Summary 4 (t5-base):
#  "The Price Is Right" for the first time in eight years, a TV legend returned to doing what he does best. "The Price Is Right" for the first time in eight years. "The Price Is Right"..
#
# Generated Summary 5 (t5-base):
#  Yahya Rashid, 19, was arrested at Luton airport on Tuesday after he arrived on a flight from Istanbul, police said. he's been charged with engaging in conduct in preparation of acts of terrorism, and with engaging in conduct with the intention of assisting others to commit acts of terrorism.
# rouge1 score of summary1:0.5076923076923078
# rouge2 score of summary1:0.328125
# rougeL score of summary1:0.30769230769230765
# rouge1 score of summary2:0.28865979381443296
# rouge2 score of summary2:0.042105263157894736
# rougeL score of summary2:0.16494845360824742
# rouge1 score of summary3:0.136986301369863
# rouge2 score of summary3:0.056338028169014086
# rougeL score of summary3:0.136986301369863
# rouge1 score of summary4:0.2545454545454545
# rouge2 score of summary4:0.1509433962264151
# rougeL score of summary4:0.2545454545454545
# rouge1 score of summary5:0.5060240963855421
# rouge2 score of summary5:0.2962962962962962
# rougeL score of summary5:0.45783132530120485
#
# ROUGE Scores for t5-base: {'rouge1': 0.33878159076152004, 'rouge2': 0.17476159676992403, 'rougeL': 0.2644007685034155}
# BLEU score of summary1: 0.2879795953115584
# BLEU score of summary2: 0.04048335454093097
# BLEU score of summary3: 0.0680099029628596
# BLEU score of summary4: 0.14907119849998599
# BLEU score of summary5: 0.23957871187497748
# Average BLEU score: 0.1570245526380625

# %%
ws = wb.create_sheet(title="t5-large")

# %%
run_summarization("t5-large")
# Out:
# Generated Summary 1 (t5-large):
#  in the number of people sentenced to death last year. At least 2,466 people are confirmed to have been handed the sentence last year, an increase of 28% in the number of people sentenced to death. At least 2,466 people are confirmed to have been handed the sentence last year, an increase of 28% in the number of people sentenced to death. The report, released Wednesday, also notes that executions are increasing globally despite the decline.
#
# Generated Summary 2 (t5-large):
#  Getty, 47, had "several health issues," a police spokesman says. the coroner's preliminary assessment is there was no foul play involved, a police spokesman says. Andrew Getty had "several health issues," a police spokesman says.
#
# Generated Summary 3 (t5-large):
#  and be out of the country by Monday.. "It will be like a typhoon.". "We do not know what the impact will be once it will make landfall," Dry said.. (CNN) for flash floods and landslides. to be on guard for flash floods and landslides. for.. and.. and and......
#
# Generated Summary 4 (t5-large):
#  , Barker returned to "The Price Is Right" for the first time in eight years.s.s. (CNN) (CNN)For the first time in eight years, a TV legend returned to doing what he does best.CNN)For the first time in eight years. " for eight years. ". host Bob Barker " host Boby.......
#
# Generated Summary 5 (t5-large):
#  .. A 19-year-old man was charged Wednesday with terror offenses after he was arrested as he returned to Britain from Turkey.. London (CNN)A 19-year-old man was charged Wednesday with terror offenses after he was arrested as he returned to Britain from Turkey.. after he was arrested as he returned to Britain from Turkey.......on.....
# rouge1 score of summary1:0.3181818181818182
# rouge2 score of summary1:0.07692307692307693
# rougeL score of summary1:0.2272727272727273
# rouge1 score of summary2:0.39999999999999997
# rouge2 score of summary2:0.07692307692307693
# rougeL score of summary2:0.3
# rouge1 score of summary3:0.21333333333333332
# rouge2 score of summary3:0.0
# rougeL score of summary3:0.16
# rouge1 score of summary4:0.34285714285714286
# rouge2 score of summary4:0.1764705882352941
# rougeL score of summary4:0.2571428571428572
# rouge1 score of summary5:0.2857142857142857
# rouge2 score of summary5:0.0898876404494382
# rougeL score of summary5:0.17582417582417584
#
# ROUGE Scores for t5-large: {'rouge1': 0.31201731601731597, 'rouge2': 0.08404087650617723, 'rougeL': 0.22404795204795208}
# BLEU score of summary1: 0.09176629354822471
# BLEU score of summary2: 0.07434420778661383
# BLEU score of summary3: 0.022280162707422328
# BLEU score of summary4: 0.16413036132965794
# BLEU score of summary5: 0.11429089766391894
# Average BLEU score: 0.09336238460716755

# %%
wb.save('/content/drive/My Drive/summary_results.xlsx')
